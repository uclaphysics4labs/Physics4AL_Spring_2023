# %% [markdown]
# # Damped Oscillations

# %% [markdown]
# In this notebook, we will import our damped oscillation data, determine the lifetime of the decay, and use this to obtain a best-fit for the oscillations. First, let's mount our drive and import the neccessary modules.

# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('drive')

# Import required libraries
import numpy as np
import scipy.optimize as sp
import matplotlib.pyplot as plt

# %% [markdown]
# Next, read in the data from the Arduino. Extract the position in meters and time in seconds. We'll plot this data to determine our guess parameters.

# %%
# Read in the data from the Arduino
# read_in_array = 

# Extract the time and position of the Arduino. Convert the time from milliseconds to seconds and the position from centimeters to meters
# time = 
# position = 

# Plot the position of the Arduino as a function of time


# Include title, axis labels

# %% [markdown]
# To properly analyze our data, we have to extract a range of good data and obtain a guess for our offset

# %%
# Change the start and stop indecies to cover a range of 3-4 oscillations
# start_index = 0
# stop_index = 10

# Plot the position vs. array index
# plt.scatter(np.arange(len(position)), position)

# Include a title and axis labels

# These green vertical lines are the start and stop times. The red line is the offset guess
# Change the start and stop times so that they intersect the red line at the same points where they intersect the data
# plt.vlines([start_index, stop_index], np.min(position), np.max(position), color = 'green', linewidth = 3)

# guess_offset = np.mean(position[start_index:stop_index])

# plt.hlines(guess_offset, start_index, stop_index, color = 'red', linewidth = 3)

# %% [markdown]
# Now we can determine our other guess fit parameters and extract our data window. Use $\omega = \frac{2\pi}{T}$ to determine the angular frequency of oscillations. We will also extract two peaks to determine the lifetime of the decay.

# %%
# Extract the data within our specified window
# time_window = time[start_index:stop_index] - time[start_index]
# position_window = position[start_index:stop_index]

# Change these two horizontal line positions so that they align with two peaks of the data
# peak_pos_1 = 
# peak_pos_2 = 

# Change these two vertical line positions so that they align with the previously obtained peaks
# peak_time_1 = 
# peak_time_2 = 

# Plot the position vs. time. Include a title and axis labels


# Plot the horizontal lines for the peak positions and the vertical lines for the peak times
# plt.hlines([peak_pos_1, peak_pos_2], time_window[0], time_window[-1], color = 'red', linewidth = 3)
# plt.vlines([peak_time_1, peak_time_2], np.min(position_window), np.max(position_window), color = 'green', linewidth = 3)

# %%
# Write in our fit function here


# Obtain our other guess fit parameters

# guess_amplitude = 
# guess_angular_frequency = 
# guess_phase = 0

# Use the formula for the lifetime to obtain the guess for the lifetime
# guess_lifetime = 

# Combine these into our guess parameters for our fit function
# guess_params = np.array([])

# %% [markdown]
# Finally, we use ```curve_fit``` to obtain the best-fit parameters and plot our data with the best fit.

# %%
# Use curve_fit to obtain the best-fit parameters


# Plot the position vs. time and best-fit


# Include title, axis labels, legend

# %% [markdown]
# # Energy in Harmonic Oscillations

# %% [markdown]
# To analyze the energy in our harmonic oscillator, we will compute the kinetic and potential energy of the system as a function of time. The potential energy in the spring is given by $PE=\frac{1}{2}k\left(x-x_0\right)^2$, and the kinetic energy is given by $KE=\frac{1}{2}mv^2$. Here, $x_0$ is the equillibrium position of the spring (best-fit offset here), $k$ is the spring constant of the spring, and $m$ is the mass of the Arduino setup that you weighed earlier this lab.

# %%
# Obtain the potential energy of the oscillator from the position best-fit


# Theoretically differentiate the position by taking the derivative of the fit funciton to find the velocity


# Obtain the kinetic energy of the oscillator from the velocity


# Plot the potential, kinetic, and total energy as a function of time
